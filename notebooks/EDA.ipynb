# %%
# 1. PREPARANDO LAS LIBRERÍAS
import pandas as pd
import plotly.express as px

# 2. Cargar tus datos económicos mexicanos. LA FUENTE ES: 
# "https://datos.gob.mx/dataset/sistema_informacion_empresarial_mexicano"
data = pd.read_csv('C:/Users/Juan Luis Cortés/Documents/GitHub/eco-mex/data/datosgob_2024.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147851 entries, 0 to 147850
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   razon_social        147780 non-null  object
#  1   estado              147851 non-null  object
#  2   municipio           147851 non-null  object
#  3   domicilio           147851 non-null  object
#  4   colonia             147851 non-null  object
#  5   cp                  147851 non-null  int64
#  6   telefono            113520 non-null  object
#  7   e_mail              88671 non-null   object
#  8   giro                147594 non-null  object
#  9   scian               147851 non-null  int64
#  10  rango_de_empleados  147851 non-null  object
#  11  registrado_por      147851 non-null  object
#  12  fn_razon_social     2 non-null       float64
#  13  fn_telefono         113498 non-null  float64
#  14  fn_e_mail           19 non-null      float64
# ...

# %%
# ¿PORQUÉ LOS DATOS DE LAS COLUMNAS: fn_razon_social, fn_telefono, fn_e_mail Y 
# fn_giro SON FLOTANTES? 
# QUIERO VER UNA MUESTRA DE LOS DATOS.

data.sample(10)
# Out:
#                                       razon_social            estado  \
# 123038                       SUPERMERCADO MICHELLE        Tamaulipas
# 100823                                   ELASTOTEC            México
# 96341                  ESTACION DE SERVICIO PEGASO           Jalisco
# 105776  ESENCIALES EN COCINAS Y MUEBLES S.A DE C.V            Puebla
# 144627                        ABARROTES DEL VILLAR         Zacatecas
# 3659                                 OXXO MERCEDES            México
# 143818                           PASTELERIA ALICIA           Yucatán
# 45080                  ARTICULOS MILITARES EL JEFE         Chihuahua
# 109176                                     BRIOCHE         Querétaro
# 67083                            AFORE XXI BANORTE  Ciudad de México
#
#                   municipio  \
# 123038            Matamoros
# 100823  Naucalpan de Juárez
# 96341               Zapopan
# 105776               Puebla
# 144627               Calera
# 3659                 Toluca
# ...

# %%
# SE PUEDEN OBSERVAR FALLAS EN LA ESTRUCTURA DEL DATASET ORIGINAL. LAS COLUMNAS ANTES 
# MENCIONADAS NO APORTAN DATOS SIGNIFICATIVOS O VALIOSOS, POR EL MOMENTO.

# %%
# 3. TRAS HABER OBSERVADO LA ORGANIZACIÓN DEL DATASET, 
# PROCEDO A HACER UN ANÁLISIS DE LAS LOCALIDADES. 

# Análisis de distribución geográfica
print("Distribución por estado:")
estado_counts = data['estado'].value_counts()
print(estado_counts.head(10))

# Crear un gráfico de barras con los top 10 estados
import plotly.express as px

fig = px.bar(
    x=estado_counts.head(10).index, 
    y=estado_counts.head(10).values,
    title="Top 10 Estados con más registros",
    labels={'x': 'Estado', 'y': 'Número de registros'}
)
fig.show()
# Out:
# Distribución por estado:
# estado
# Ciudad de México                   28557
# Nuevo León                         18466
# Jalisco                            11798
# México                             11078
# Tamaulipas                         10238
# Chihuahua                           7618
# Veracruz de Ignacio de la Llave     7423
# Yucatán                             6033
# Puebla                              5083
# Guanajuato                          4851
# Name: count, dtype: int64

# %%
# Esta distribución refleja perfectamente las diferencias en formalización empresarial y 
# capacidad administrativa entre los Estados de México y su respectiva urbanización.
# Es decir, a mayores recursos administrativos, gubernamentales y de acceso a la tecnología, 
# es más probable que se puedan registrar los giros empresariales que se encuentrar en 
# determinadas localidades.

# %%
# Antes de avanzar, quiero saber si el dataset contiene los datos de los 32 estados. 
print(data['estado'].nunique())
# Out:
# 32

# %%
# Correcto. Hay 32 estados, por lo que en el dataset existen registros de todas las 
# administraciones locales o estados de México.
# Esto me servirá para poder establecer una relación con los datos locales, para 
# establecer códigos que puedan usarse para describir las actividades locales y por lo tanto
# el desarrollo por sectores económicos.  
# Ahora quiero saber los giros de los tres estados con 
# más registros: Ciudad de México, Nuevo León y Jalisco.

# Filtrar solo Ciudad de México
cdmx = data[data['estado'] == 'Ciudad de México']
# Filtrar solo Nuevo León
nuevol = data[data['estado'] == 'Nuevo León']
# Filtrar solo Jalisco
jalisco = data[data['estado'] == 'Jalisco']

#Giros en las tres ciudades
giros_cdmx = cdmx['giro'].nunique()
print("El número de giros en CDMX son:", giros_cdmx)
giros_nl = nuevol['giro'].nunique()
print("El número de giros en Nuevo León son:", giros_nl)
giros_jlsc = jalisco['giro'].nunique()
print("El número de giros en Jalisco son:", giros_jlsc)
print()

# Los giros más importantes
top_10_cdmx = cdmx['giro'].value_counts().head(10)
print("Giros más importantes en CDMX", top_10_cdmx)
print()

# PARA QUE SALGAN LOS DATOS COMPLETOS, SE SEPARARON LOS RESULTADOS DE NUEVO LEON Y JALISCO.
# Out:
# El número de giros en CDMX son: 6487
# El número de giros en Nuevo León son: 2683
# El número de giros en Jalisco son: 5291
#
# Giros más importantes en CDMX giro
# FARMACIA                                          1650
# ABARROTES                                         1365
# RESTAURANTE                                        685
# MENSAJERIA                                         439
# FARMACIAS Y MINISUPER                              359
# TIENDA DE CONVENIENCIA                             350
# OTROS SERVICIOS DE APOYO A LOS NEGOCIOS            284
# COMERCIO AL POR MENOR DE TELEFONIA                 269
# COMERCIO AL POR MENOR DE MUEBLES PARA EL HOGAR     266
# COMERCIO AL POR MENOR DE TIENDAS DE ABARROTES      261
# Name: count, dtype: int64

# %%
top_10_nuevol = nuevol['giro'].value_counts().head(10)
print("Giros más importantes en Nuevo León", top_10_nuevol)
print()
top_10_jal = jalisco['giro'].value_counts().head(10)
print("Giros más importantes en Jalisco", top_10_jal)
# Out:
# Giros más importantes en Nuevo León giro
# .                      9716
# ABARROTES               465
# TIENDA DE ABARROTES     392
# ..                      288
# FERRETERIA              235
# FRUTERIA                135
# RESTAURANTE             130
# TORTILLERIA             109
# RESTAURANTES             93
# FRUTAS Y LEGUMBRES       78
# Name: count, dtype: int64
#
# Giros más importantes en Jalisco giro
# ABARROTES                                                                           357
# FARMACIA                                                                            261
# Comercio al por menor de alimentos y bebidas en tiendas de abarrotes, ultramarin    206
# CONSTRUCCION DE OBRAS DE URBANIZACION                                               173
# ABARROTES CON VTA DE CERV. BOTELLA CERRADA                                          146
# MINISUPER                                                                           120
# ...

# %%
# SE OBSERVAN MUCHOS DATOS DUPLICADOS EN LA COLUMNA "GIRO", EN LAS TRES CIUDADES REPRESENTANTES 
# PRINCIPALES DE LA ECONOMÍA MEXICANA.

# PARA EL RESTO DEL ESTUDIO Y CON EL AFAN DE REPETIR ESTE PROCEDIMIENTO EN UN FUTURO PARA LOS
# DATOS DE TODOS LOS ESTADOS, SE PROCEDE A TOMAR LOS DATOS DE LA CIUDAD DE MÉXICO Y UNIFICAR 
# LOS GIROS QUE APARECEN, DE FORMA TAL QUE PUEDA CLASIFICARSE DE ACUERDO A LA SIGUIENTE 
# ESTRUCTURA:

# SECTOR PRIMARIO: MATERIAS PRIMAS: Agricultura, Ganadería, Pesca, Minería, Silvicultura
# SECTOR SECUNDARIO: INDUSTRIAS: Manufactura, Construcción, Producción energética
# SECTOR TERCIARIO: SERVICIOS: Comercio, Trasporte, Turismo, Educación, Salud, 
# Servicios profesionales, Servicios técnicos.

# POSIBLEMENTE LOS GIROS DE LOS NEGOCIOS SE VAN A AMPLIAR, A PARTIR DEL ESTUDIO DE LOS 
# VALORES INDIVIDUALES DE LOS GIROS DE LA CIUDAD DE MÉXICO. 

# SE TOMARÁ LA CIUDAD DE MÉXICO AL SER LA MUESTRA MÁS GRANDE DE TODO EL DATASET. 
# DADO QUE YA SE TENÍA EL FILTRO EN "cdmx", SE PROCEDE A REVISA QUE DICHA MUESTRA SE 
# ENCUENTRE ESTABLECIDA: 

cdmx.info()
cdmx.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28557 entries, 49398 to 147739
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   razon_social        28556 non-null  object
#  1   estado              28557 non-null  object
#  2   municipio           28557 non-null  object
#  3   domicilio           28557 non-null  object
#  4   colonia             28557 non-null  object
#  5   cp                  28557 non-null  int64
#  6   telefono            27561 non-null  object
#  7   e_mail              23840 non-null  object
#  8   giro                28555 non-null  object
#  9   scian               28557 non-null  int64
#  10  rango_de_empleados  28557 non-null  object
#  11  registrado_por      28557 non-null  object
#  12  fn_razon_social     0 non-null      float64
#  13  fn_telefono         27561 non-null  float64
#  14  fn_e_mail           0 non-null      float64
# ...

# %%
# AHORA, CON EL OBJETO DE LIMPIAR LOS DATOS DEL GIRO Y TENER ASÍ UNA MEJOR ORGANIZACIÓN, SE 
# OBTIENEN TODOS LOS VALORES DE LA COLUMNA GIRO

val_giro = cdmx['giro'].nunique()
print(f"La columna tiene {val_giro} valores únicos")
# Out:
# La columna tiene 6487 valores únicos

# %%
# EL PRESENTE DATASET NO SOLO CONTIENE UN NÚMERO EXAGERADO DE VALORES ÚNICOS PARA LAS 
# ACTIVIDADES QUE PUEDEN SER DESCRITAS FÁCILMENTE DENTRO DE LAS CATEGORÍAS PROPUESTAS, SINO 
# QUE TAMBIÉN CONTIENE COLUMNAS QUE NO NOS SIRVEN PARA EL ANÁLISIS DE LOS SECTORES ECONÓMICOS 
# MEXICANOS. POR LO QUE SE HARÁ UN NUEVO DATASET A PARTIR DE ESTE SEGUNDO.

columnas_deseadas = ['razon_social','municipio','giro','rango_de_empleados']
cdmx_clean = cdmx[columnas_deseadas]
cdmx_clean.info()
cdmx_clean.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28557 entries, 49398 to 147739
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   razon_social        28556 non-null  object
#  1   municipio           28557 non-null  object
#  2   giro                28555 non-null  object
#  3   rango_de_empleados  28557 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB
#                                razon_social          municipio  \
# 69880                   PLAZA LOPEZ COTILLA         Cuauhtémoc
# 62547                FARMACIAS DE SIMILARES      Benito Juárez
# 57698                 POLIMEROS Y DERIVADOS     Álvaro Obregón
# 56790  TLM SERVICIOS BIOMEDICOS Y ROBOTICOS         Iztapalapa
# 51839                         MOTEL LA FLOR  Gustavo A. Madero
#
#                                                     giro rango_de_empleados
# ...

# %%
# SE CREARÁ UNA COLUMNA QUE PERMITA ASIGNAR UNA ACTIVIDAD CADA EMPRESA CONFORME A SU GIRO EN UN SECTOR 
# ECONÓMICO PARTICULAR.ASÍ MISMO SE TRABAJARÁ EN UNA FUNCIÓN QUE PERMITA IDENTIFICAR PALABRAS 
# USADAS EN LA COLUMNA "GIRO" PARA ASIGNAR DICHA EMPRESA A UN SECTOR PARTICULAR. 

# SE CONVIERTEN LOS CARACTERES DE LA COLUMNA GIRO EN MINUSCULAS: 
cdmx_clean['giro'] = cdmx_clean['giro'].str.lower()

# CREANDO LA NUEVA COLUMNA:
cdmx_clean['actividad'] = 'sin clasificar'
cdmx_clean.sample(2)
# Out:
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\565674662.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\565674662.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     razon_social            municipio  \
# 53912       BOUTIQUE TINKER BELL           Iztapalapa
# 75852  APOYO ECONOMICO  FAMILIAR  Venustiano Carranza
#
# ...

# %%
# Veamos qué tipos de datos hay en la columna 'giro'
print("Tipos de datos en 'giro':")
print(cdmx_clean['giro'].dtype)
print("\nPrimeros 10 valores:")
print(cdmx_clean['giro'].head(10))
print("\nValores nulos:")
print(cdmx_clean['giro'].isnull().sum())
# Out:
# Tipos de datos en 'giro':
# object
#
# Primeros 10 valores:
# 49398                                oficinas corporativas
# 49399                                         construccion
# 49400                                         construccion
# 49401                                         construcción
# 49402    suministro, fabricacion, e instalacion de cubi...
# 49403    servicios de ingeniería,atención y gestoria so...
# 49404                                         construccion
# 49405            servicio de alineacion y venta de llantas
# 49406      alineacion y balanceo de automoviles y camiones
# 49407               reparacion y mantenimiento automoviles
# Name: giro, dtype: object
#
# Valores nulos:
# 2

# %%
# SE GENERA Y TRABAJA LA FUNCIÓN:

# TENGAMOS PRESENTES LOS SECTORES ECONÓMICOS: 
# SECTOR PRIMARIO: MATERIAS PRIMAS: Agricultura, Ganadería, Pesca, Minería, Silvicultura
# SECTOR SECUNDARIO: INDUSTRIAS: Manufactura, Construcción, Producción energética
# SECTOR TERCIARIO: SERVICIOS: Comercio, Trasporte, Turismo, Educación, Salud, 
# Servicios profesionales, Servicios técnicos.

# DATASET
cdmx_clean

def clasificar_sector(giro_texto):
    
    # Palabras clave para agricultura (sector PRIMARIO)
    agricultura_keywords = ['agricultura','agricultura orgánica','agricultura organica','cultivo','cultivos','cosecha','cosechas','labranza','siembra','riego','monocultivo','policultivo','agroecología','agroecologia','agrobiotecnología','agrobiotecnologia','bioestimulación']
    # Palabras clave para ganaderia (sector PRIMARIO)
    ganaderia_keywords = ['ganadería','ganado','vacuno','vacas','toros','bueyes','bobino','ovino','porcino','puerco','puercos','cerdo','cerdos','caprino','cabras','equino','caballos','yeguas','avícola','avicola','críadero de','ciradero','criaderos','cunícola','cunicola','conejo','conejos','apicultura','cria de abeja','explotación de abejas','helicicultura','potrero','establo','vaquería','vaqueria','engorde','ordeña','ordeñar','pecuario','agropecuario']
    # Palabras clave para pesca (sector PRIMARIO)
    pesca_keywords = ['pesca','acuicultura','pesqueria','pesquería']
    # Palabras clave para mineria (sector PRIMARIO)
    mineria_keywords = ['mineria','extraccion','mina','mineral','excavación','excavacion','perforación','perforacion','tronadura','lixiviación','fundición']
    # Palabras clave para silvicultura (sector PRIMARIO)
    silvicultura_keywords = ['silvicultura','aprovechamiento forestal','forestal','reforestación','reforestacion','aclareo','restauración ecológica','ecologica','ecológica','ecológico','ecologico','tala','deforestación','deforestacion']
    # Palabras clave para manufactura (sector SECUNDARIO)
    manufactura_keywords = ['fabricación','fabricacion','fabrica','elaboración','elaboracion','ensamble','empaque','industri','manufacturera','manufactura','transformacion de marmol']
    # Palabras clave para construccion (sector SECUNDARIO)
    construccion_keywords = ['alumino','aluminio','obra civil','constructora','costructoras','construccion','construcción','constrccion','corporativo','corporativas','metales','transformacion de aluminio','supervisión deobra','galvanoplastia','proyectos','laminado','encapsulado','tablaroca','impermeabilizantes']
    # Palabras clave para produccion energetica (sector SECUNDARIO)
    energia_keywords = ['gasolineria','gas','generacion','generación','energia','energía','petroliferos','petroleos','combustibles','plantas de luz']
    # Palabras clave para comercio (sector terciario)
    comercio_keywords = ['abarrotes','abrrotes','aceites','accesorios','accesorios y equipo','accesirios','accsesorios','aislamientos','alimento para','alimentos para','alimento apara mascotas','alimentos de','alimentos','alimento preparados','agua','anillos','artículos','articulos','art.','art','autos','automotriz','automotrices','aotomotriz','autopartes','artesanías','artesanias','articuloes','al por menor','al por mayor','al mayoreo','al menudeo','azulejos','básculas','basculas','busiteria','bisuteria','bisutería','billetes de loteria','blancos','bolsas','botanas','bonetería','boneteria','cafe de cafe','cámaras','camaras','camisetas','camicetas','camiseria','candiles','calcetines','carne','carnicería','carniceria','carenceria','carnicria','carteras','calzado','ceramica','chiles','chocolates','cigarros','colorantes','comercializadora','ciomercializadora','comecializadora','comercializacion','comercialización','comercial','comercio','computadoras','corbatas','cortinas','corseteria','cosmeticos','cremeria','cremería','cristal','cuadros','cv','c/v','c/vta','desechables','distribucion','distribución','distribuidora','distribuidor','dulces','dulceria','dulcería','elasticos','electronica','electrodomésticos','electrodomesticos','embutidos','encajes','equipo','equipos','equipo de','equipo deportivo','equipo médico','equipo medico','farmacia','farmcacia','farmaceutica','farmaceuticos','farmauceuticos','farmacos','ferreteria','floreria','florería','flores','filtros','figuras','follajes','fragancias','frituras','fruta','galletas','globos','grasas','gorras','hebillas','heladeria','helado','helados','herramientas','huevo','insumos','instrumentos musicales','jabones','jarcieria','jarceria','joyas','joyeria','joyería','juguetes','jugueteria','jugeteria','lacteos','lamparas','legumbres','lenceria','letreros','llantas','licores','libro','libros','lirbos','libreria','librería','librerías','librerias','loncheria','lotería','loteria','lubricantes','maderería','madereria','manualidades','manualiades','marcos','marisco','mariscos','material','materias primas','medidores','merceria','mercería','miscelánea','miscelanea','miscelania','micelanea','minisuper','mini super','mobiliario','mochilas','motocicletas','mueblería','muebleria','muebles','naturista','novia','pan','panaderia','pasteleria','paleteria','pañal','pañales','papel','papeleria','papelería','pepeleria','peleteria','peluches','perfume','perfumes','perfumeria','pefumeria','periodico','periodicos','persianas','pescado','pescados','pescaderia','plasticos','plásticos','playeras','pigmentos','pintura','pinturas','pintutras','pisos','pizzeria','pollo','polleria','pollería','posters','postres','pulseras','purificadora','productos','por mayoreo','por menudeo','puros','quimicos para','radiadores','recaudería','recauderia','regalo','regalos','rfegalos','refacciones','refaccionaria','refrescos','refaccdione','relojes','reposteria','revistas','rodamientos','ropa','rosticeria','salchichonería','salchichoneria','sandias','semillas','sierras','supermercado','suplementos','telas','tenis','textil','tienda','tlapeleria','tlapaleria','tlapalería','tomates','tornillos','tostaderia','tuercas','uniformes','valvulas de control', 'venta','verduras','vidriero','vinos','vinateria','veladoras','vta','venta','vent','vemta','vestidos','zapaterias','zapateria','zapatos','rosalba garduño']
    # Palabras clave para trasporte (sector terciario)
    transporte_keywords = ['fletes','transporte','autotransporte','trasportacion','transportacion','transportista','trasporte de carga','trasporte','traslado']
    # Palabras clave para turismo (sector terciario)
    turismo_keywords = ['alimentos y bebidas','aliemntos y bebidas','alimentos preparados','bar','boliche','boliches','cafetería','cafeteria','cantina','casa de huespedes','casino','excursiones','hotel','hospedaje','hostal','turismo','turistico','turisticos','restaurante','inmuebles','motel','moteles','preparacion','pista de hielo','taqueria','taqueteria','viaje','viajes','parque','recreativo']
    # Palabras clave para educacion (sector terciario)
    educacion_keywords = ['academia','bachilletaro','capacitacion','centro de estudios','colegio','cursos','educacion','educación','educativa','educativo','educativos','enseñanza','escuelas','escuela','estudios superiores','guardería','guarderia','jardín de niños','kinder','preescolar','prescolar','primaria','secundaria','universidad']
    # Palabras clave para salud (sector terciario) 
    salud_keywords = ['acondicionamiento','acontecimiento fisico','acondisionamiento','analisis clinicos','aromaterapia','consulta','consultorio','clínica','clinicas','clinica','dentista','dental','deportivo','depocito dental','deportivos','gimnasio','gymnasio','gymnacio','fisioterapia','hospitales','hospital','laboratorio','laboratorios','médico','medico','medica','medicamentos','medicinas','ortopedista','optica','óptica','octica','ortopedia','podologo','podología','podologia','reacondiicionamiento','recreativos','rehabilitación física','salud','veterinaria','veterinario','veterinarios','vetereniaria','veterinaría','veterianria']
    # Palabras clave para servicios profesionales diversos (sector terciario)
    profesionales_keywords = ['abogados','aduana','aduanal','anduanal','aduanales','aduaneros','agencia aduanal','agencias aduanales','afianzadoras','afianzadora','arquitectura','arquitectos','asesoria','aseguradora','asesoría','asalariado','auditoria','banco','banca','bolsa de valores','belleza','certificaciones','ciencia','científico','cinematografía','cinematografia','cinematográfica','cinematografica','consultoría','consultoria','contabilidad','contable','contables','corredor publico mercantil','crediticia','crediticio','creditos','diseños','diseño','diseno','deposito','depositos','desarrollo de software','desarrollo inmobiliario','edición de software','editor','editora','escrituras publicas','espectaculos','estetica','estética','finaciera','financiera','financiero','financieras','financiamento','finanzas','fondos','fotográfico','fotografico','fotografía','fotografia','fotofrafia','holding','informatico','informático','informática','informatica','ingeniería','ingenieria','ingeniero','ingeniera','ingenieros','inmobiliairia','imobiliaria','inmobiliario','invercion','inversion','investigación','investigacion','juridico','juridicos','legales','marketing','mercadotecnia','mercadeo','numismatica','peluqueria','produccion de programas','profesional','profesionales','profecionales','profesionista','profesionistas','programas de','peliculas','poligráficas','publicidad','radio','relaciones publicas','relaciones públicas','reaseguradora','representacion y promocion','satelital','seguro','seguros','sistemas computacionales','sistemas de telepeaje','tecnologías','telecomunicacion','telecomunicaciones','tenedora de acciones','topografia','topograficos','medios masivos en comunicacion']
    # Palabras clave para servicios tecnicos (sector terciario)
    tecnicos_keywords = ['administradora','administracion','administración','administrativo','administrativos','administratuivos','aerografía','agencia de colocacion','agencias noticiosas','almacenamiento','alquiler','alq.','alquile','anuncios','aparatos','arrendamiento','arendamiento','arrendamineto','artes graficas','asistencia social','asistencias social','asociaciones','autolavado','auto lavado','automoviles','baño','baños','bienes raices','billar','billares','blindaje','bodega','bordado','boutique','call center','casa de cambio','casa de empeño','centro cambiario','centro de cambio','cerrajeria','cobranza','cobranzas','colocacion de personal','copiado','copias','controladora','contratacion de personal','control de acceso','convención','convenciones','cultural','custodio','custodia','decoración','decoracion','deshechos','desazolve','desechos','desperdicio','desperdicios','difusion','edicion','elevadores','empeño','empeños','en la nube','entrenador de perros','entretenimiento','equipo contra incendios','esoterico','esoterismo','establecimiento','estacionamiento','estaciomaniento','eventos','fundación','fundacion','funeraria','funerarios','funerales','herrajes','herreria','impresion','impresión','impreciones','impresores','miprecion','imprenta','internet','inmobiliaria','inmobilaria','inmobiliarias','inmobiliarios','instalaciones','instalacion','instalación','juegos','lavandería','lavanderia','limpieza','llamadas','logistica','lonas','mantenimiento','maquinas fotograficas','mecanico','mensajeria','monitoreo','naves industriales','orfebrería','orfebreria','organización','organizacion','organizaciones','paqueteria','paquetería','pension','pensión','planchaduria','plomeria','prestamos','préstamos','procesamiento informativo','proteccion','recreativas','renta','reparacion','reparación','rep.','rep','recicladora','reciclaje','reclutamiento','refrigeracion','residuo','residuos','revelado','salón','salon','salones','sanitarios','sastreria','seguridad','selección de personal','seleccion de personal','serigrafia','servicio','servicios','serv.','servicos','sitio de taxis','subastas','suministro de personal','superficies deportivas','taller','tapiceria','tecnico','técnico','tintorería','tintoreria','toldos','torno','verificentro','vidriera','vidrieria']
    
    # Verificar si el valor es nulo o no es string
    if pd.isna(giro_texto) or not isinstance(giro_texto, str):
        return 'sin clasificar'
    
    # Buscar si alguna palabra clave está en el texto
    for keyword in agricultura_keywords:
        if keyword in giro_texto:
            return 'agricultura'
        
    for keyword in pesca_keywords:
        if keyword in giro_texto:
            return 'pesca'
    
    for keyword in silvicultura_keywords:
        if keyword in giro_texto:
            return 'silvicultura'
    
    for keyword in ganaderia_keywords:
        if keyword in giro_texto:
            return 'ganadería'  
    
    for keyword in mineria_keywords:
        if keyword in giro_texto:
            return 'minería'
        
    for keyword in manufactura_keywords:
        if keyword in giro_texto:
            return 'manufactura'
        
    for keyword in construccion_keywords:
        if keyword in giro_texto:
            return 'construcción'

    for keyword in energia_keywords:
        if keyword in giro_texto:
            return 'producción energética'

    for keyword in comercio_keywords:
        if keyword in giro_texto:
            return 'comercio'

    for keyword in transporte_keywords:
        if keyword in giro_texto:
            return 'transporte'

    for keyword in educacion_keywords:
        if keyword in giro_texto:
            return 'educación'

    for keyword in salud_keywords:
        if keyword in giro_texto:
            return 'salud'

    for keyword in turismo_keywords:
        if keyword in giro_texto:
            return 'turismo'        

    for keyword in profesionales_keywords:
        if keyword in giro_texto:
            return 'servicios profesionales'

    for keyword in tecnicos_keywords:
        if keyword in giro_texto:
            return 'servicios técnicos'
    
    # Si no encuentra ninguna coincidencia
    return 'sin clasificar'

cdmx_clean['actividad'] = cdmx_clean['giro'].apply(clasificar_sector)

# TRAS ITERAR LA PASADA FUNCIÓN UN NUMERO NO DETERMINADO DE VECES, SE LOGRÓ REDUCIR 

# VALORES ASIGNADOS A 'GIRO':
print(cdmx_clean['actividad'].value_counts())

# SUMA TOTAL DE TODOS LOS VALORES
total = cdmx_clean['actividad'].value_counts().sum()
print(f"Total de registros: {total}")

print()

# PORCENTAJE DE LOS SECTORES EMPRESARIALES EN LA CIUDAD DE MÉXICO.
print(cdmx_clean['actividad'].value_counts(normalize=True) * 100)
# Out:
# actividad
# comercio                   18789
# servicios técnicos          2688
# servicios profesionales     1917
# turismo                     1659
# manufactura                  917
# salud                        892
# educación                    455
# construcción                 361
# producción energética        303
# transporte                   297
# sin clasificar               103
# silvicultura                  60
# pesca                         53
# minería                       33
# agricultura                   23
# ganadería                      7
# Name: count, dtype: int64
# Total de registros: 28557
#
# actividad
# comercio                   65.794726
# servicios técnicos          9.412753
# servicios profesionales     6.712890
# turismo                     5.809434
# manufactura                 3.211122
# salud                       3.123577
# educación                   1.593305
# construcción                1.264138
# producción energética       1.061036
# ...

# %%
# TRAS HABER AGRUPADO LAS ACTIVIDADES DE LAS EMPRESAS DE LA CIUDAD DE MÉXICO, 
# BUSCAREMOS CLASIFICAR LAS EMPRESAS EN LOS SECTORES ECONÓMICOS, PARA EXTENDER EL MODELO A 
# OTROS ESTADOS O A LA MISMA ECONOMÍA DEL PAIS: 


import numpy as np

# Actividades
primario = ['minería','agricultura','ganadería','pesca', 'silvicultura'] 
secundario = ['manufactura', 'construcción', 'producción energética']
terciario = ['comercio', 'transporte', 'turismo', 'educación', 'salud','servicios profesionales', 'servicios técnicos']

# Condiciones (nota las comas al final de cada línea)
condiciones = [
    cdmx_clean['actividad'].isin(primario),
    cdmx_clean['actividad'].isin(secundario),
    cdmx_clean['actividad'].isin(terciario)
]

# Valores
valores = ['primario','secundario','terciario']

cdmx_clean['sector_economico'] = np.select(condiciones, valores, default='sin clasificar')


print(cdmx_clean.sample(3))
# Out:
#                      razon_social              municipio  \
# 69052  LABORATORIO MEDICO POLANCO             Cuauhtémoc
# 51465            GARMONT SISTEMAS  Cuajimalpa de Morelos
# 67534                      FISCAL             Cuauhtémoc
#
#                                                     giro rango_de_empleados  \
# 69052  servicios de laboratorios y medicos  y de diag...             0 a 10
# 51465  servicios de proteccion y cuatodia mediante el...            11 a 50
# 67534     comercio al por menor de muebles para el hogar             0 a 10
#
#                 actividad sector_economico
# 69052               salud        terciario
# 51465  servicios técnicos        terciario
# 67534            comercio        terciario
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\3824072342.py:23: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# HASTA AHORA HEMOS VISTO UN DATASET CUYO ESTUDIO SE DIFICULTÓ POR LAS MUCHAS FORMAS QUE TENÍAN 
# LOS DATOS CONTENIDOS. ASÍ MISMO OBSERVAMOS QUE PARA LOS OBJETIVOS DE ESTE ESTUDIO, LA MAYOR 
# PARTE DE LOS DATOS NO ERAN DE UTILIDAD DIRECTA. 

# ES POR ESO QUE SE GENERARÁ UN SEGUNDO DATASET A PARTIR DEL ORIGINAL, A FIN DE INCLUIR 
# ÚNICAMENTE EL NOMBRE, EL ESTADO, LA ACTIVIDAD Y EL SECTOR ECONÓMICO QUE SE PUEDAN OBTENER 
# DE AQUEL. 

# PRIMERO OBTENDREMOS LOS DATOS BUSCADOS EN EL DATASET ORIGINAL. 

columnas = ['razon_social','estado','giro']
data_clean = data[columnas]

# VERIFICARÉ LA CREACIÓN DE DATASET DESEADO
data_clean.info()
data_clean.sample(3)

# SE CONVIERTEN LOS CARACTERES DE LA COLUMNA GIRO EN MINUSCULAS PARA SU MEJOR MANEJO: 
data_clean['giro'] = data_clean['giro'].str.lower()

# CREANDO LA NUEVA COLUMNA:
data_clean['actividad'] = 'sin clasificar'
data_clean.sample(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147851 entries, 0 to 147850
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   razon_social  147780 non-null  object
#  1   estado        147851 non-null  object
#  2   giro          147594 non-null  object
# dtypes: object(3)
# memory usage: 3.4+ MB
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\2202696184.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\2202696184.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# CONFORME A LO OBSERVADO EN LA CIUDAD DE MÉXICO, SE PROCEDE A CLASIFICAR DE MANERA MÁS CLARA
# LAS ACTIVIDADES DE CADA EMPRESA REGISTRADA CON LAS AUTORIDADES MEXICANAS. 

def clasificar_sector(giro_texto):
    
    # Palabras clave para agricultura (sector PRIMARIO)
    agricultura_keywords = ['agricultura','agricultura orgánica','agricultura organica','cultivo','cultivos','cosecha','cosechas','labranza','siembra','riego','monocultivo','policultivo','agroecología','agroecologia','agrobiotecnología','agrobiotecnologia','bioestimulación']
    # Palabras clave para ganaderia (sector PRIMARIO)
    ganaderia_keywords = ['ganadería','ganado','vacuno','vacas','toros','bueyes','bobino','ovino','porcino','puerco','puercos','cerdo','cerdos','caprino','cabras','equino','caballos','yeguas','avícola','avicola','críadero de','ciradero','criaderos','cunícola','cunicola','conejo','conejos','apicultura','cria de abeja','explotación de abejas','helicicultura','potrero','establo','vaquería','vaqueria','engorde','ordeña','ordeñar','pecuario','agropecuario']
    # Palabras clave para pesca (sector PRIMARIO)
    pesca_keywords = ['pesca','acuicultura','pesqueria','pesquería']
    # Palabras clave para mineria (sector PRIMARIO)
    mineria_keywords = ['mineria','extraccion','mina','mineral','excavación','excavacion','perforación','perforacion','tronadura','lixiviación','fundición']
    # Palabras clave para silvicultura (sector PRIMARIO)
    silvicultura_keywords = ['silvicultura','aprovechamiento forestal','forestal','reforestación','reforestacion','aclareo','restauración ecológica','ecologica','ecológica','ecológico','ecologico','tala','deforestación','deforestacion']
    # Palabras clave para manufactura (sector SECUNDARIO)
    manufactura_keywords = ['fabricación','fabricacion','fabrica','elaboración','elaboracion','ensamble','empaque','industri','manufacturera','manufactura','transformacion de marmol']
    # Palabras clave para construccion (sector SECUNDARIO)
    construccion_keywords = ['alumino','aluminio','obra civil','constructora','costructoras','construccion','construcción','constrccion','corporativo','corporativas','metales','transformacion de aluminio','supervisión deobra','galvanoplastia','proyectos','laminado','encapsulado','tablaroca','impermeabilizantes']
    # Palabras clave para produccion energetica (sector SECUNDARIO)
    energia_keywords = ['gasolineria','gas','generacion','generación','energia','energía','petroliferos','petroleos','combustibles','plantas de luz']
    # Palabras clave para comercio (sector terciario)
    comercio_keywords = ['abarrotes','abrrotes','aceites','accesorios','accesorios y equipo','accesirios','accsesorios','aislamientos','alimento para','alimentos para','alimento apara mascotas','alimentos de','alimentos','alimento preparados','agua','anillos','artículos','articulos','art.','art','autos','automotriz','automotrices','aotomotriz','autopartes','artesanías','artesanias','articuloes','al por menor','al por mayor','al mayoreo','al menudeo','azulejos','básculas','basculas','busiteria','bisuteria','bisutería','billetes de loteria','blancos','bolsas','botanas','bonetería','boneteria','cafe de cafe','cámaras','camaras','camisetas','camicetas','camiseria','candiles','calcetines','carne','carnicería','carniceria','carenceria','carnicria','carteras','calzado','ceramica','chiles','chocolates','cigarros','colorantes','comercializadora','ciomercializadora','comecializadora','comercializacion','comercialización','comercial','comercio','computadoras','corbatas','cortinas','corseteria','cosmeticos','cremeria','cremería','cristal','cuadros','cv','c/v','c/vta','desechables','distribucion','distribución','distribuidora','distribuidor','dulces','dulceria','dulcería','elasticos','electronica','electrodomésticos','electrodomesticos','embutidos','encajes','equipo','equipos','equipo de','equipo deportivo','equipo médico','equipo medico','farmacia','farmcacia','farmaceutica','farmaceuticos','farmauceuticos','farmacos','ferreteria','floreria','florería','flores','filtros','figuras','follajes','fragancias','frituras','fruta','galletas','globos','grasas','gorras','hebillas','heladeria','helado','helados','herramientas','huevo','insumos','instrumentos musicales','jabones','jarcieria','jarceria','joyas','joyeria','joyería','juguetes','jugueteria','jugeteria','lacteos','lamparas','legumbres','lenceria','letreros','llantas','licores','libro','libros','lirbos','libreria','librería','librerías','librerias','loncheria','lotería','loteria','lubricantes','maderería','madereria','manualidades','manualiades','marcos','marisco','mariscos','material','materias primas','medidores','merceria','mercería','miscelánea','miscelanea','miscelania','micelanea','minisuper','mini super','mobiliario','mochilas','motocicletas','mueblería','muebleria','muebles','naturista','novia','pan','panaderia','pasteleria','paleteria','pañal','pañales','papel','papeleria','papelería','pepeleria','peleteria','peluches','perfume','perfumes','perfumeria','pefumeria','periodico','periodicos','persianas','pescado','pescados','pescaderia','plasticos','plásticos','playeras','pigmentos','pintura','pinturas','pintutras','pisos','pizzeria','pollo','polleria','pollería','posters','postres','pulseras','purificadora','productos','por mayoreo','por menudeo','puros','quimicos para','radiadores','recaudería','recauderia','regalo','regalos','rfegalos','refacciones','refaccionaria','refrescos','refaccdione','relojes','reposteria','revistas','rodamientos','ropa','rosticeria','salchichonería','salchichoneria','sandias','semillas','sierras','supermercado','suplementos','telas','tenis','textil','tienda','tlapeleria','tlapaleria','tlapalería','tomates','tornillos','tostaderia','tuercas','uniformes','valvulas de control', 'venta','verduras','vidriero','vinos','vinateria','veladoras','vta','venta','vent','vemta','vestidos','zapaterias','zapateria','zapatos','rosalba garduño']
    # Palabras clave para trasporte (sector terciario)
    transporte_keywords = ['fletes','transporte','autotransporte','trasportacion','transportacion','transportista','trasporte de carga','trasporte','traslado']
    # Palabras clave para turismo (sector terciario)
    turismo_keywords = ['alimentos y bebidas','aliemntos y bebidas','alimentos preparados','bar','boliche','boliches','cafetería','cafeteria','cantina','casa de huespedes','casino','excursiones','hotel','hospedaje','hostal','turismo','turistico','turisticos','restaurante','inmuebles','motel','moteles','preparacion','pista de hielo','taqueria','taqueteria','viaje','viajes','parque','recreativo']
    # Palabras clave para educacion (sector terciario)
    educacion_keywords = ['academia','bachilletaro','capacitacion','centro de estudios','colegio','cursos','educacion','educación','educativa','educativo','educativos','enseñanza','escuelas','escuela','estudios superiores','guardería','guarderia','jardín de niños','kinder','preescolar','prescolar','primaria','secundaria','universidad']
    # Palabras clave para salud (sector terciario) 
    salud_keywords = ['acondicionamiento','acontecimiento fisico','acondisionamiento','analisis clinicos','aromaterapia','consulta','consultorio','clínica','clinicas','clinica','dentista','dental','deportivo','depocito dental','deportivos','gimnasio','gymnasio','gymnacio','fisioterapia','hospitales','hospital','laboratorio','laboratorios','médico','medico','medica','medicamentos','medicinas','ortopedista','optica','óptica','octica','ortopedia','podologo','podología','podologia','reacondiicionamiento','recreativos','rehabilitación física','salud','veterinaria','veterinario','veterinarios','vetereniaria','veterinaría','veterianria']
    # Palabras clave para servicios profesionales diversos (sector terciario)
    profesionales_keywords = ['abogados','aduana','aduanal','anduanal','aduanales','aduaneros','agencia aduanal','agencias aduanales','afianzadoras','afianzadora','arquitectura','arquitectos','asesoria','aseguradora','asesoría','asalariado','auditoria','banco','banca','bolsa de valores','belleza','certificaciones','ciencia','científico','cinematografía','cinematografia','cinematográfica','cinematografica','consultoría','consultoria','contabilidad','contable','contables','corredor publico mercantil','crediticia','crediticio','creditos','diseños','diseño','diseno','deposito','depositos','desarrollo de software','desarrollo inmobiliario','edición de software','editor','editora','escrituras publicas','espectaculos','estetica','estética','finaciera','financiera','financiero','financieras','financiamento','finanzas','fondos','fotográfico','fotografico','fotografía','fotografia','fotofrafia','holding','informatico','informático','informática','informatica','ingeniería','ingenieria','ingeniero','ingeniera','ingenieros','inmobiliairia','imobiliaria','inmobiliario','invercion','inversion','investigación','investigacion','juridico','juridicos','legales','marketing','mercadotecnia','mercadeo','numismatica','peluqueria','produccion de programas','profesional','profesionales','profecionales','profesionista','profesionistas','programas de','peliculas','poligráficas','publicidad','radio','relaciones publicas','relaciones públicas','reaseguradora','representacion y promocion','satelital','seguro','seguros','sistemas computacionales','sistemas de telepeaje','tecnologías','telecomunicacion','telecomunicaciones','tenedora de acciones','topografia','topograficos','medios masivos en comunicacion']
    # Palabras clave para servicios tecnicos (sector terciario)
    tecnicos_keywords = ['administradora','administracion','administración','administrativo','administrativos','administratuivos','aerografía','agencia de colocacion','agencias noticiosas','almacenamiento','alquiler','alq.','alquile','anuncios','aparatos','arrendamiento','arendamiento','arrendamineto','artes graficas','asistencia social','asistencias social','asociaciones','autolavado','auto lavado','automoviles','baño','baños','bienes raices','billar','billares','blindaje','bodega','bordado','boutique','call center','casa de cambio','casa de empeño','centro cambiario','centro de cambio','cerrajeria','cobranza','cobranzas','colocacion de personal','copiado','copias','controladora','contratacion de personal','control de acceso','convención','convenciones','cultural','custodio','custodia','decoración','decoracion','deshechos','desazolve','desechos','desperdicio','desperdicios','difusion','edicion','elevadores','empeño','empeños','en la nube','entrenador de perros','entretenimiento','equipo contra incendios','esoterico','esoterismo','establecimiento','estacionamiento','estaciomaniento','eventos','fundación','fundacion','funeraria','funerarios','funerales','herrajes','herreria','impresion','impresión','impreciones','impresores','miprecion','imprenta','internet','inmobiliaria','inmobilaria','inmobiliarias','inmobiliarios','instalaciones','instalacion','instalación','juegos','lavandería','lavanderia','limpieza','llamadas','logistica','lonas','mantenimiento','maquinas fotograficas','mecanico','mensajeria','monitoreo','naves industriales','orfebrería','orfebreria','organización','organizacion','organizaciones','paqueteria','paquetería','pension','pensión','planchaduria','plomeria','prestamos','préstamos','procesamiento informativo','proteccion','recreativas','renta','reparacion','reparación','rep.','rep','recicladora','reciclaje','reclutamiento','refrigeracion','residuo','residuos','revelado','salón','salon','salones','sanitarios','sastreria','seguridad','selección de personal','seleccion de personal','serigrafia','servicio','servicios','serv.','servicos','sitio de taxis','subastas','suministro de personal','superficies deportivas','taller','tapiceria','tecnico','técnico','tintorería','tintoreria','toldos','torno','verificentro','vidriera','vidrieria']
    
    # Verificar si el valor es nulo o no es string
    if pd.isna(giro_texto) or not isinstance(giro_texto, str):
        return 'sin clasificar'
    
    # Buscar si alguna palabra clave está en el texto
    for keyword in agricultura_keywords:
        if keyword in giro_texto:
            return 'agricultura'
        
    for keyword in pesca_keywords:
        if keyword in giro_texto:
            return 'pesca'
    
    for keyword in silvicultura_keywords:
        if keyword in giro_texto:
            return 'silvicultura'
    
    for keyword in ganaderia_keywords:
        if keyword in giro_texto:
            return 'ganadería'  
    
    for keyword in mineria_keywords:
        if keyword in giro_texto:
            return 'minería'
        
    for keyword in manufactura_keywords:
        if keyword in giro_texto:
            return 'manufactura'
        
    for keyword in construccion_keywords:
        if keyword in giro_texto:
            return 'construcción'

    for keyword in energia_keywords:
        if keyword in giro_texto:
            return 'producción energética'

    for keyword in comercio_keywords:
        if keyword in giro_texto:
            return 'comercio'

    for keyword in transporte_keywords:
        if keyword in giro_texto:
            return 'transporte'

    for keyword in educacion_keywords:
        if keyword in giro_texto:
            return 'educación'

    for keyword in salud_keywords:
        if keyword in giro_texto:
            return 'salud'

    for keyword in turismo_keywords:
        if keyword in giro_texto:
            return 'turismo'        

    for keyword in profesionales_keywords:
        if keyword in giro_texto:
            return 'servicios profesionales'

    for keyword in tecnicos_keywords:
        if keyword in giro_texto:
            return 'servicios técnicos'
    
    # Si no encuentra ninguna coincidencia
    return 'sin clasificar'

data_clean['actividad'] = data_clean['giro'].apply(clasificar_sector)


# VALORES ASIGNADOS A 'GIRO':
print(data_clean['actividad'].value_counts())

# SUMA TOTAL DE TODOS LOS VALORES
total = data_clean['actividad'].value_counts().sum()
print(f"Total de registros: {total}")

print()

# PORCENTAJE DE LOS SECTORES EMPRESARIALES EN MÉXICO.
print("Porcentaje de los sectores económicos en México")
print(data_clean['actividad'].value_counts(normalize=True) * 100)
# Out:
# actividad
# comercio                   82389
# sin clasificar             18409
# servicios técnicos          9665
# construcción                7177
# turismo                     6124
# servicios profesionales     5936
# manufactura                 5479
# salud                       3786
# transporte                  3524
# producción energética       2188
# educación                   1538
# silvicultura                 626
# minería                      394
# pesca                        246
# ganadería                    217
# agricultura                  153
# Name: count, dtype: int64
# Total de registros: 147851
#
# Porcentaje de los sectores económicos en México
# actividad
# comercio                   55.724344
# sin clasificar             12.451049
# servicios técnicos          6.536987
# construcción                4.854211
# turismo                     4.142008
# servicios profesionales     4.014853
# manufactura                 3.705758
# ...

# %%
# DEJANDO AFUERA LOS DATOS NULOS, HEMOS LOGRADO CATEGORIZAR APROXIMADAMENTE UN 87 % DE LA 
# ECONOMÍA FORMAL MEXICANA. 

# SE PROCEDE AHORA A AGRUPAR LAS ACTIVIDADES POR SECTOR Y A ELIMINAR LA COLUMNA 'GIRO' AL 
# TENER MEJORES DATOS. 

# Actividades
primario = ['minería','agricultura','ganadería','pesca', 'silvicultura'] 
secundario = ['manufactura', 'construcción', 'producción energética']
terciario = ['comercio', 'transporte', 'turismo', 'educación', 'salud','servicios profesionales', 'servicios técnicos']

# Condiciones (nota las comas al final de cada línea)
condiciones = [
    data_clean['actividad'].isin(primario),
    data_clean['actividad'].isin(secundario),
    data_clean['actividad'].isin(terciario)
]

# Valores
valores = ['primario','secundario','terciario']

data_clean['sector_economico'] = np.select(condiciones, valores, default='sin clasificar')

del data_clean['giro']

print(data_clean.sample(3))
# Out:
#            razon_social               estado     actividad sector_economico
# 85428           ILUSIÓN              Hidalgo   manufactura       secundario
# 73590  SANBORN HERMANOS     Ciudad de México      comercio        terciario
# 34008  COMEX (CARRANZA)  Baja California Sur  construcción       secundario
# C:\Users\Juan Luis Cortés\AppData\Local\Temp\ipykernel_2704\1015800685.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# SE EXTRAEN LOS DATOS EMPRESARIALES MEXICANOS PARA SU MANEJO EN LA APLICACIÓN. 
data_clean.to_csv('data_clean.csv', index=False)

print(data_clean['estado'].value_counts())
# Out:
# estado
# Ciudad de México                   28557
# Nuevo León                         18466
# Jalisco                            11798
# México                             11078
# Tamaulipas                         10238
# Chihuahua                           7618
# Veracruz de Ignacio de la Llave     7423
# Yucatán                             6033
# Puebla                              5083
# Guanajuato                          4851
# Coahuila de Zaragoza                4385
# Sinaloa                             4240
# Baja California                     3345
# Quintana Roo                        3153
# Michoacán de Ocampo                 3075
# Durango                             1981
# Zacatecas                           1857
# Baja California Sur                 1833
# San Luis Potosí                     1784
# Nayarit                             1711
# Chiapas                             1474
# Morelos                             1250
# Querétaro                           1043
# ...

# %%
# Sectores económicos en México

import plotly.graph_objects as go

fig = go.Figure(data=[go.Histogram(x=data_clean['sector_economico'])])

# Opcional: añadir un título al gráfico 
fig.update_layout(title_text='Distribución de los sectores económicos')

# Mostrar el gráfico Plotly
fig.show()

# %%
# Configuración de los sectores económicos en México. 

print(data_clean['sector_economico'].value_counts())
# Out:
# sector_economico
# terciario         112962
# sin clasificar     18409
# secundario         14844
# primario            1636
# Name: count, dtype: int64
